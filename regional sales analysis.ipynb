# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# ## Problem Statement
#
# XYZ company 2014-2018 sales data to iddentify key revenue and profit drivers across products , channelsand regions uncover seasional treands and outliers and align preformance aganest budgets , Use these insights to optimize pricing , promotions and market expansion for sustainable growth and reduced concentration risk

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading all sheets in excel file

XL_sheet = pd.read_excel("Regional Sales Dataset.xlsx" , sheet_name= None)

# %%
XL_sheet
# Out:
# {'Sales Orders':         OrderNumber  OrderDate  Customer Name Index      Channel  \
#  0       SO - 000225 2014-01-01                  126    Wholesale
#  1      SO - 0003378 2014-01-01                   96  Distributor
#  2      SO - 0005126 2014-01-01                    8    Wholesale
#  3      SO - 0005614 2014-01-01                   42       Export
#  4      SO - 0005781 2014-01-01                   73    Wholesale
#  ...             ...        ...                  ...          ...
#  64099  SO - 0007573 2018-02-28                   74    Wholesale
#  64100  SO - 0007706 2018-02-28                   51       Export
#  64101  SO - 0007718 2018-02-28                  136  Distributor
#  64102  SO - 0008084 2018-02-28                  158  Distributor
#  64103  SO - 0008654 2018-02-28                   22  Distributor
#
#        Currency Code Warehouse Code  Delivery Region Index  \
#  0               USD         AXW291                    364
# ...

# %%
df_lst =[]
for i in XL_sheet:
    print(i)
    df_lst.append(i)

print(df_lst)
# Out:
# Sales Orders
# Customers
# Regions
# State Regions
# Products
# 2017 Budgets
# ['Sales Orders', 'Customers', 'Regions', 'State Regions', 'Products', '2017 Budgets']

# %%
# Extracting all sheets , Assigning sheets to named dataframes

df_sales = XL_sheet['Sales Orders']
df_Customers = XL_sheet['Customers']
df_Regions = XL_sheet['Regions']
df_state_regions = XL_sheet['State Regions']
df_Products = XL_sheet['Products']
df_Budget = XL_sheet["2017 Budgets"]

# %% [markdown]
# # Data understanding

# %% [markdown]
# ### shape

# %%
print(df_sales.shape)
print(df_Customers.shape)
print(df_Regions.shape)
print(df_state_regions.shape)
print(df_Products.shape)
print(df_Budget.shape)
# Out:
# (64104, 12)
# (175, 2)
# (994, 15)
# (49, 3)
# (30, 2)
# (30, 2)

# %%
lst_dfs = [df_sales, df_Customers, df_Regions, df_state_regions, df_Products, df_Budget]

for i in lst_dfs:
    print(f" shape is {i.shape}")
# Out:
#  shape is (64104, 12)
#  shape is (175, 2)
#  shape is (994, 15)
#  shape is (49, 3)
#  shape is (30, 2)
#  shape is (30, 2)

# %%
dfs = {
    "df_sales": df_sales,
    "df_Customers": df_Customers,
    "df_Regions": df_Regions,
    "df_state_regions": df_state_regions,
    "df_Products": df_Products,
    "df_Budget": df_Budget
}

for name, df in dfs.items():
    print(f"{name} shape is {df.shape}")
# Out:
# df_sales shape is (64104, 12)
# df_Customers shape is (175, 2)
# df_Regions shape is (994, 15)
# df_state_regions shape is (49, 3)
# df_Products shape is (30, 2)
# df_Budget shape is (30, 2)

# %% [markdown]
# ### info()

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64104 entries, 0 to 64103
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   OrderNumber                64104 non-null  object
#  1   OrderDate                  64104 non-null  datetime64[ns]
#  2   Customer Name Index        64104 non-null  int64
#  3   Channel                    64104 non-null  object
#  4   Currency Code              64104 non-null  object
#  5   Warehouse Code             64104 non-null  object
#  6   Delivery Region Index      64104 non-null  int64
#  7   Product Description Index  64104 non-null  int64
#  8   Order Quantity             64104 non-null  int64
#  9   Unit Price                 64104 non-null  float64
#  10  Line Total                 64104 non-null  float64
#  11  Total Unit Cost            64104 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(4)
# ...

# %%
df_Regions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 994 entries, 0 to 993
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             994 non-null    int64
#  1   name           994 non-null    object
#  2   county         994 non-null    object
#  3   state_code     994 non-null    object
#  4   state          994 non-null    object
#  5   type           994 non-null    object
#  6   latitude       994 non-null    float64
#  7   longitude      994 non-null    float64
#  8   area_code      994 non-null    int64
#  9   population     994 non-null    int64
#  10  households     994 non-null    int64
#  11  median_income  994 non-null    int64
#  12  land_area      994 non-null    int64
#  13  water_area     994 non-null    int64
#  14  time_zone      994 non-null    object
# dtypes: float64(2), int64(7), object(6)
# memory usage: 116.6+ KB

# %%
df_Budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  30 non-null     object
#  1   2017 Budgets  30 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 612.0+ bytes

# %%
df_Customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer Index  175 non-null    int64
#  1   Customer Names  175 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.9+ KB

# %%
df_state_regions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Column1  49 non-null     object
#  1   Column2  49 non-null     object
#  2   Column3  49 non-null     object
# dtypes: object(3)
# memory usage: 1.3+ KB

# %%
df_Budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  30 non-null     object
#  1   2017 Budgets  30 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 612.0+ bytes

# %% [markdown]
# ### columns of each dataframe

# %%
df_sales.columns
# Out:
# Index(['OrderNumber', 'OrderDate', 'Customer Name Index', 'Channel',
#        'Currency Code', 'Warehouse Code', 'Delivery Region Index',
#        'Product Description Index', 'Order Quantity', 'Unit Price',
#        'Line Total', 'Total Unit Cost'],
#       dtype='object')

# %%
df_Customers.columns
# Out:
# Index(['Customer Index', 'Customer Names'], dtype='object')

# %%
df_Products.columns
# Out:
# Index(['Index', 'Product Name'], dtype='object')

# %%
df_Budget.columns
# Out:
# Index(['Product Name', '2017 Budgets'], dtype='object')

# %%
df_Regions.columns
# Out:
# Index(['id', 'name', 'county', 'state_code', 'state', 'type', 'latitude',
#        'longitude', 'area_code', 'population', 'households', 'median_income',
#        'land_area', 'water_area', 'time_zone'],
#       dtype='object')

# %%
df_state_regions.columns   ## need to change the column name
# Out:
# Index(['Column1', 'Column2', 'Column3'], dtype='object')

# %%
df_state_regions.head()
# Out:
#       Column1     Column2 Column3
# 0  State Code       State  Region
# 1          AL     Alabama   South
# 2          AR    Arkansas   South
# 3          AZ     Arizona    West
# 4          CA  California    West

# %%
df_state_regions.columns = df_state_regions.iloc[0]   # set first row as header
df_state_regions = df_state_regions[1:]               # remove the first row from data
df_state_regions = df_state_regions.reset_index(drop=True)

# %%
df_state_regions.columns
# Out:
# Index(['State Code', 'State', 'Region'], dtype='object', name=0)

# %% [markdown]
# ### head() all dataframes

# %%
df_sales.head()
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  Line Total  Total Unit Cost
# ...

# %%
df_Products.head()
# Out:
#    Index Product Name
# 0      1    Product 1
# 1      2    Product 2
# 2      3    Product 3
# 3      4    Product 4
# 4      5    Product 5

# %%
df_Budget.head()
# Out:
#   Product Name  2017 Budgets
# 0    Product 1   3016489.209
# 1    Product 2   3050087.565
# 2    Product 3   2642352.432
# 3    Product 4   2885560.824
# 4    Product 5   3925424.542

# %%
df_Regions.head()
# Out:
#    id        name                                   county state_code  \
# 0   1      Auburn                               Lee County         AL
# 1   2  Birmingham           Shelby County/Jefferson County         AL
# 2   3     Decatur           Limestone County/Morgan County         AL
# 3   4      Dothan  Dale County/Houston County/Henry County         AL
# 4   5      Hoover           Shelby County/Jefferson County         AL
#
#      state  type  latitude  longitude  area_code  population  households  \
# 0  Alabama  City  32.60986  -85.48078        334       62059       21767
# 1  Alabama  City  33.52744  -86.79905        205      212461       89972
# 2  Alabama  City  34.57332  -86.99214        256       55437       22294
# 3  Alabama  City  31.23370  -85.40682        334       68567       25913
# 4  Alabama  City  33.37695  -86.80558        205       84848       32789
#
#    median_income  land_area  water_area        time_zone
# ...

# %%
df_state_regions.head()
# Out:
# 0 State Code       State Region
# 0         AL     Alabama  South
# 1         AR    Arkansas  South
# 2         AZ     Arizona   West
# 3         CA  California   West
# 4         CO    Colorado   West

# %%
df_Customers.head()
# Out:
#    Customer Index Customer Names
# 0               1  Geiss Company
# 1               2  Jaxbean Group
# 2               3     Ascend Ltd
# 3               4      Eire Corp
# 4               5   Blogtags Ltd

# %% [markdown]
# ### missing Values

# %%
print("Total null values in df_sales: ",df_sales.isnull().sum().sum())
df_sales.isnull().sum()
# Out:
# Total null values in df_sales:  0
# OrderNumber                  0
# OrderDate                    0
# Customer Name Index          0
# Channel                      0
# Currency Code                0
# Warehouse Code               0
# Delivery Region Index        0
# Product Description Index    0
# Order Quantity               0
# Unit Price                   0
# Line Total                   0
# Total Unit Cost              0
# dtype: int64

# %%
print("total null values in df_Regions:",df_Regions.isnull().sum().sum())
df_Regions.isnull().sum()
# Out:
# total null values in df_Regions: 0
# id               0
# name             0
# county           0
# state_code       0
# state            0
# type             0
# latitude         0
# longitude        0
# area_code        0
# population       0
# households       0
# median_income    0
# land_area        0
# water_area       0
# time_zone        0
# dtype: int64

# %%
print("Total null values in  df_Budget :",df_Budget.isnull().sum().sum())
df_Budget.isnull().sum()
# Out:
# Total null values in  df_Budget : 0
# Product Name    0
# 2017 Budgets    0
# dtype: int64

# %%
print("total null values in df_Customers: ",df_Customers.isnull().sum().sum())
df_Customers.isnull().sum()
# Out:
# total null values in df_Customers:  0
# Customer Index    0
# Customer Names    0
# dtype: int64

# %%
print("Total null values in df_Products: ",df_Products.isnull().sum().sum())
df_Products.isnull().sum()
# Out:
# Total null values in df_Products:  0
# Index           0
# Product Name    0
# dtype: int64

# %%
print("total null values df_state_regions:",df_state_regions.isnull().sum().sum())
df_state_regions.isnull().sum()
# Out:
# total null values df_state_regions: 0
# 0
# State Code    0
# State         0
# Region        0
# dtype: int64

# %% [markdown]
# #### duplicate values

# %%
df_sales.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_state_regions.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_Regions.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_Budget.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_Customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_Products.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Printing shape, columns, missing values, duplicates, head

# %%
dfs = {
    "df_sales": df_sales,
    "df_Customers": df_Customers,
    "df_Regions": df_Regions,
    "df_state_regions": df_state_regions,
    "df_Products": df_Products,
    "df_Budget": df_Budget
}

# %%
for name, df in dfs.items():
    print(f"\n📊 DataFrame: {name}")
    print("="*60)

    print("Shape :", df.shape)

    print("\nColumns :")
    print(df.columns.tolist())

    print("\nMissing Values :")
    print(df.isnull().sum())

    print("\nDuplicate Rows :", df.duplicated().sum())

    print("\nHead :")
    print(df.head())

    print("\n" + "#"*60)
# Out:
# 📊 DataFrame: df_sales
# ...
# Shape : (64104, 12)
#
# Columns :
# ['OrderNumber', 'OrderDate', 'Customer Name Index', 'Channel', 'Currency Code', 'Warehouse Code', 'Delivery Region Index', 'Product Description Index', 'Order Quantity', 'Unit Price', 'Line Total', 'Total Unit Cost']
#
# Missing Values :
# OrderNumber                  0
# OrderDate                    0
# Customer Name Index          0
# Channel                      0
# Currency Code                0
# Warehouse Code               0
# Delivery Region Index        0
# Product Description Index    0
# Order Quantity               0
# Unit Price                   0
# Line Total                   0
# Total Unit Cost              0
# dtype: int64
#
# Duplicate Rows : 0
#
# Head :
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# ...

# %% [markdown]
# # pandas profiling

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\sidda\AppData\Local\Programs\Python\Python312\python.exe

# %% [markdown]
# # Data cleaning and Wrangling
#
# - Data Cleaning = process of fixing or removing incorrect, missing, duplicate, or inconsistent data to improve data quality before analysis or machine learning.
#     - Goal: make data accurate, consistent, and usable
#
# - Data Wrangling = transforming raw data into a structured format suitable for analysis, visualization, and machine learning.
#     - It focuses on:
#         - combining datasets
#         - reshaping data
#         - grouping & aggregation
#         - filtering & transforming values

# %% [markdown]
# ### merging tables into one dataframe

# %%
df_sales.head()
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  Line Total  Total Unit Cost
# ...

# %%
df_Customers.head()
# Out:
#    Customer Index Customer Names
# 0               1  Geiss Company
# 1               2  Jaxbean Group
# 2               3     Ascend Ltd
# 3               4      Eire Corp
# 4               5   Blogtags Ltd

# %%
# merge sales with customers

df = df_sales.merge(
    df_Customers,
    how='left',
    left_on='Customer Name Index',
    right_on='Customer Index'
)

# %%
df.head()
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  Line Total  Total Unit Cost  Customer Index  \
# ...

# %%
# merge with products

df = df.merge(
    df_Products,
    how='left',
    left_on='Product Description Index',
    right_on='Index'
)

# %%
df_Products.head()
# Out:
#    Index Product Name
# 0      1    Product 1
# 1      2    Product 2
# 2      3    Product 3
# 3      4    Product 4
# 4      5    Product 5

# %%
df.head()
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  Line Total  Total Unit Cost  Customer Index  \
# ...

# %%
# merge with regions
df = df.merge(
    df_Regions,
    how='left',
    left_on='Delivery Region Index',
    right_on='id'
)

# %%
df_Regions.head()
# Out:
#    id        name                                   county state_code  \
# 0   1      Auburn                               Lee County         AL
# 1   2  Birmingham           Shelby County/Jefferson County         AL
# 2   3     Decatur           Limestone County/Morgan County         AL
# 3   4      Dothan  Dale County/Houston County/Henry County         AL
# 4   5      Hoover           Shelby County/Jefferson County         AL
#
#      state  type  latitude  longitude  area_code  population  households  \
# 0  Alabama  City  32.60986  -85.48078        334       62059       21767
# 1  Alabama  City  33.52744  -86.79905        205      212461       89972
# 2  Alabama  City  34.57332  -86.99214        256       55437       22294
# 3  Alabama  City  31.23370  -85.40682        334       68567       25913
# 4  Alabama  City  33.37695  -86.80558        205       84848       32789
#
#    median_income  land_area  water_area        time_zone
# ...

# %%
df
# Out:
#         OrderNumber  OrderDate  Customer Name Index      Channel  \
# 0       SO - 000225 2014-01-01                  126    Wholesale
# 1      SO - 0003378 2014-01-01                   96  Distributor
# 2      SO - 0005126 2014-01-01                    8    Wholesale
# 3      SO - 0005614 2014-01-01                   42       Export
# 4      SO - 0005781 2014-01-01                   73    Wholesale
# ...             ...        ...                  ...          ...
# 64099  SO - 0007573 2018-02-28                   74    Wholesale
# 64100  SO - 0007706 2018-02-28                   51       Export
# 64101  SO - 0007718 2018-02-28                  136  Distributor
# 64102  SO - 0008084 2018-02-28                  158  Distributor
# 64103  SO - 0008654 2018-02-28                   22  Distributor
#
#       Currency Code Warehouse Code  Delivery Region Index  \
# 0               USD         AXW291                    364
# 1               USD         AXW291                    488
# ...

# %%
# merge with state Region

df = df.merge(
    df_state_regions[['State Code','Region']],
    how='left',
    left_on='state_code',
    right_on='State Code'
)

# %%
df_state_regions
# Out:
# 0  State Code                 State     Region
# 0          AL               Alabama      South
# 1          AR              Arkansas      South
# 2          AZ               Arizona       West
# 3          CA            California       West
# 4          CO              Colorado       West
# 5          CT           Connecticut  Northeast
# 6          DC  District of Columbia      South
# 7          DE              Delaware      South
# 8          FL               Florida      South
# 9          GA               Georgia      South
# 10         HI                Hawaii       West
# 11         IA                  Iowa    Midwest
# 12         ID                 Idaho       West
# 13         IL              Illinois    Midwest
# 14         IN               Indiana    Midwest
# 15         KS                Kansas    Midwest
# 16         KY              Kentucky      South
# 17         LA             Louisiana      South
# 18         MA         Massachusetts  Northeast
# ...

# %%
df
# Out:
#         OrderNumber  OrderDate  Customer Name Index      Channel  \
# 0       SO - 000225 2014-01-01                  126    Wholesale
# 1      SO - 0003378 2014-01-01                   96  Distributor
# 2      SO - 0005126 2014-01-01                    8    Wholesale
# 3      SO - 0005614 2014-01-01                   42       Export
# 4      SO - 0005781 2014-01-01                   73    Wholesale
# ...             ...        ...                  ...          ...
# 64099  SO - 0007573 2018-02-28                   74    Wholesale
# 64100  SO - 0007706 2018-02-28                   51       Export
# 64101  SO - 0007718 2018-02-28                  136  Distributor
# 64102  SO - 0008084 2018-02-28                  158  Distributor
# 64103  SO - 0008654 2018-02-28                   22  Distributor
#
#       Currency Code Warehouse Code  Delivery Region Index  \
# 0               USD         AXW291                    364
# 1               USD         AXW291                    488
# ...

# %%
# merge with budget

df = df.merge(
    df_Budget,
    how='left',
    on='Product Name'
)

# %%
df.head()


# mearging completed
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  ...  area_code  population  households  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64104 entries, 0 to 64103
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   OrderNumber                64104 non-null  object
#  1   OrderDate                  64104 non-null  datetime64[ns]
#  2   Customer Name Index        64104 non-null  int64
#  3   Channel                    64104 non-null  object
#  4   Currency Code              64104 non-null  object
#  5   Warehouse Code             64104 non-null  object
#  6   Delivery Region Index      64104 non-null  int64
#  7   Product Description Index  64104 non-null  int64
#  8   Order Quantity             64104 non-null  int64
#  9   Unit Price                 64104 non-null  float64
#  10  Line Total                 64104 non-null  float64
#  11  Total Unit Cost            64104 non-null  float64
#  12  Customer Index             64104 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['OrderNumber', 'OrderDate', 'Customer Name Index', 'Channel',
#        'Currency Code', 'Warehouse Code', 'Delivery Region Index',
#        'Product Description Index', 'Order Quantity', 'Unit Price',
#        'Line Total', 'Total Unit Cost', 'Customer Index', 'Customer Names',
#        'Index', 'Product Name', 'id', 'name', 'county', 'state_code', 'state',
#        'type', 'latitude', 'longitude', 'area_code', 'population',
#        'households', 'median_income', 'land_area', 'water_area', 'time_zone',
#        'State Code', 'Region', '2017 Budgets'],
#       dtype='object')

# %%
Df_lst= df.columns.to_list()

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv('temp_file.csv') # just to store the merged dataframe before forther cleaning

# %%
df.head()
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  ...  area_code  population  households  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64104 entries, 0 to 64103
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   OrderNumber                64104 non-null  object
#  1   OrderDate                  64104 non-null  datetime64[ns]
#  2   Customer Name Index        64104 non-null  int64
#  3   Channel                    64104 non-null  object
#  4   Currency Code              64104 non-null  object
#  5   Warehouse Code             64104 non-null  object
#  6   Delivery Region Index      64104 non-null  int64
#  7   Product Description Index  64104 non-null  int64
#  8   Order Quantity             64104 non-null  int64
#  9   Unit Price                 64104 non-null  float64
#  10  Line Total                 64104 non-null  float64
#  11  Total Unit Cost            64104 non-null  float64
#  12  Customer Index             64104 non-null  int64
# ...

# %%
# checking duplicate columns values

for i in range(len(df.columns)):
    for j in range(i+1, len(df.columns)):

        col1 = df.columns[i]
        col2 = df.columns[j]

        if df[col1].equals(df[col2]):

            print(f"Same values -> {col1} & {col2}")
# Out:
# Same values -> Customer Name Index & Customer Index
# Same values -> Delivery Region Index & id
# Same values -> Product Description Index & Index
# Same values -> state_code & State Code

# %%
duplicate_value_columns = []

for i in range(len(df.columns)):
    for j in range(i+1, len(df.columns)):

        col1 = df.columns[i]
        col2 = df.columns[j]

        if df[col1].equals(df[col2]):

            duplicate_value_columns.append((col1, col2))

duplicate_value_columns
# Out:
# [('Customer Name Index', 'Customer Index'),
#  ('Delivery Region Index', 'id'),
#  ('Product Description Index', 'Index'),
#  ('state_code', 'State Code')]

# %%
### we have to drop the duplicate columns

[('Customer Name Index', 'Customer Index'),
 ('Delivery Region Index', 'id'),
 ('Product Description Index', 'Index'),
 ('state_code', 'State Code')]
# Out:
# [('Customer Name Index', 'Customer Index'),
#  ('Delivery Region Index', 'id'),
#  ('Product Description Index', 'Index'),
#  ('state_code', 'State Code')]

# %%
# from ('Customer Name Index', 'Customer Index') ------> Customer Index
# from ('Product Description Index', 'Index') ----------> Index
# from ('Delivery Region Index', 'id') -------> id
# from ('state_code', 'State Code') -------> State Code

# Clean up redundant columns

cols_to_drop = ['Customer Index', 'Index', 'id', 'State Code']

df = df.drop(columns=cols_to_drop, errors='ignore')

df.head(5)
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  ...  longitude  area_code population  \
# ...

# %%
df
# Out:
#         OrderNumber  OrderDate  Customer Name Index      Channel  \
# 0       SO - 000225 2014-01-01                  126    Wholesale
# 1      SO - 0003378 2014-01-01                   96  Distributor
# 2      SO - 0005126 2014-01-01                    8    Wholesale
# 3      SO - 0005614 2014-01-01                   42       Export
# 4      SO - 0005781 2014-01-01                   73    Wholesale
# ...             ...        ...                  ...          ...
# 64099  SO - 0007573 2018-02-28                   74    Wholesale
# 64100  SO - 0007706 2018-02-28                   51       Export
# 64101  SO - 0007718 2018-02-28                  136  Distributor
# 64102  SO - 0008084 2018-02-28                  158  Distributor
# 64103  SO - 0008654 2018-02-28                   22  Distributor
#
#       Currency Code Warehouse Code  Delivery Region Index  \
# 0               USD         AXW291                    364
# 1               USD         AXW291                    488
# ...

# %%
# covertion all column values to lower case for consistencity and easier access

df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['ordernumber', 'orderdate', 'customer name index', 'channel',
#        'currency code', 'warehouse code', 'delivery region index',
#        'product description index', 'order quantity', 'unit price',
#        'line total', 'total unit cost', 'customer names', 'product name',
#        'name', 'county', 'state_code', 'state', 'type', 'latitude',
#        'longitude', 'area_code', 'population', 'households', 'median_income',
#        'land_area', 'water_area', 'time_zone', 'region', '2017 budgets'],
#       dtype='object')

# %%
df.to_csv('cleaned_Regional_sales_df_with_all_columns.csv')

# %%
# Drop un-necessary columns 

 # List only the columns you want to KEEP, now including the broader 'region'
cols_to_keep = [
    'ordernumber',        # unique order ID
    'orderdate',          # date when the order was placed
    'customer names',     # customer who placed the order
    'channel',            # sales channel (e.g., Wholesale, Distributor)
    'product name',       # product purchased
    'order quantity',     # number of units ordered
    'unit price',         # price per unit
    'line total',         # revenue for this line item (qty × unit_price)
    'total unit cost',    # company’s cost for this line item
    'state_code',         # two-letter state code
    'state',              # full state name
    'region',             # broader U.S. region (e.g., South, West)
    'latitude',           # latitude of delivery city
    'longitude',          # longitude of delivery city
    '2017 budgets'        # budget target for this product in 2017
]

# %%
# Subset the DataFrame to only these columns

df = df[cols_to_keep]

# %%
df.head()
# Out:
#     ordernumber  orderdate    customer names      channel product name  \
# 0   SO - 000225 2014-01-01     Rhynoodle Ltd    Wholesale   Product 27
# 1  SO - 0003378 2014-01-01    Thoughtmix Ltd  Distributor   Product 20
# 2  SO - 0005126 2014-01-01   Amerisourc Corp    Wholesale   Product 26
# 3  SO - 0005614 2014-01-01  Colgate-Pa Group       Export    Product 7
# 4  SO - 0005781 2014-01-01     Deseret Group    Wholesale    Product 8
#
#    order quantity  unit price  line total  total unit cost state_code  \
# 0               6      2499.1     14994.6         1824.343         GA
# 1              11      2351.7     25868.7         1269.918         IN
# 2               6       978.2      5869.2          684.740         CA
# 3               7      2338.3     16368.1         1028.852         IN
# 4               8      2291.4     18331.2         1260.270         CT
#
#          state     region  latitude  longitude  2017 budgets
# ...

# %%
 # Rename to more Pythonic / self-explanatory names

df = df.rename(columns={
    'ordernumber'      : 'order_number',   # snake_case for consistency
    'orderdate'        : 'order_date',     # date of the order
    'customer names'   : 'customer_name',  # customer who placed it
    'product name'     : 'product_name',   # product sold
    'order quantity'   : 'quantity',       # units sold
    'unit price'       : 'unit_price',     # price per unit in USD
    'line total'       : 'revenue',        # revenue for the line item
    'total unit cost'  : 'cost',           # cost for the line item
    'state_code'       : 'state',          # two-letter state code
    'state'            : 'state_name',     # full state name
    'region'           : 'us_region',      # broader U.S. region
    'latitude'         : 'lat',            # latitude (float)
    'longitude'        : 'lon',            # longitude (float)
    '2017 budgets'     : 'budget'          # 2017 budget target (float)
})

# %%
df.head()
# Out:
#    order_number order_date     customer_name      channel product_name  \
# 0   SO - 000225 2014-01-01     Rhynoodle Ltd    Wholesale   Product 27
# 1  SO - 0003378 2014-01-01    Thoughtmix Ltd  Distributor   Product 20
# 2  SO - 0005126 2014-01-01   Amerisourc Corp    Wholesale   Product 26
# 3  SO - 0005614 2014-01-01  Colgate-Pa Group       Export    Product 7
# 4  SO - 0005781 2014-01-01     Deseret Group    Wholesale    Product 8
#
#    quantity  unit_price  revenue      cost state   state_name  us_region  \
# 0         6      2499.1  14994.6  1824.343    GA      Georgia      South
# 1        11      2351.7  25868.7  1269.918    IN      Indiana    Midwest
# 2         6       978.2   5869.2   684.740    CA   California       West
# 3         7      2338.3  16368.1  1028.852    IN      Indiana    Midwest
# 4         8      2291.4  18331.2  1260.270    CT  Connecticut  Northeast
#
#         lat        lon       budget
# 0  32.08354  -81.09983   964940.231
# ...

# %%
# Blank out budgets for non-2017 orders
df.loc[df['order_date'].dt.year != 2017, 'budget'] = pd.NA

# %%
# Inspect
df[['order_date','product_name','revenue','budget']].head(10)
# Out:
#   order_date product_name  revenue  budget
# 0 2014-01-01   Product 27  14994.6     NaN
# 1 2014-01-01   Product 20  25868.7     NaN
# 2 2014-01-01   Product 26   5869.2     NaN
# 3 2014-01-01    Product 7  16368.1     NaN
# 4 2014-01-01    Product 8  18331.2     NaN
# 5 2014-01-01   Product 23  57412.3     NaN
# 6 2014-01-01    Product 1  20120.1     NaN
# 7 2014-01-01   Product 25  10452.0     NaN
# 8 2014-01-01   Product 13  19262.5     NaN
# 9 2014-01-01   Product 14  34974.0     NaN

# %%
df.isnull().sum()
# Out:
# order_number         0
# order_date           0
# customer_name        0
# channel              0
# product_name         0
# quantity             0
# unit_price           0
# revenue              0
# cost                 0
# state                0
# state_name           0
# us_region            0
# lat                  0
# lon                  0
# budget           48841
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64104 entries, 0 to 64103
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_number   64104 non-null  object
#  1   order_date     64104 non-null  datetime64[ns]
#  2   customer_name  64104 non-null  object
#  3   channel        64104 non-null  object
#  4   product_name   64104 non-null  object
#  5   quantity       64104 non-null  int64
#  6   unit_price     64104 non-null  float64
#  7   revenue        64104 non-null  float64
#  8   cost           64104 non-null  float64
#  9   state          64104 non-null  object
#  10  state_name     64104 non-null  object
#  11  us_region      64104 non-null  object
#  12  lat            64104 non-null  float64
#  13  lon            64104 non-null  float64
#  14  budget         15263 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(7)
# memory usage: 7.3+ MB

# %%
df.to_csv('final_cleaned_sales_df.csv', index=False)

# %%
df_2017 = df[df['order_date'].dt.year ==2017]

# %%
df_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15263 entries, 46363 to 61625
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_number   15263 non-null  object
#  1   order_date     15263 non-null  datetime64[ns]
#  2   customer_name  15263 non-null  object
#  3   channel        15263 non-null  object
#  4   product_name   15263 non-null  object
#  5   quantity       15263 non-null  int64
#  6   unit_price     15263 non-null  float64
#  7   revenue        15263 non-null  float64
#  8   cost           15263 non-null  float64
#  9   state          15263 non-null  object
#  10  state_name     15263 non-null  object
#  11  us_region      15263 non-null  object
#  12  lat            15263 non-null  float64
#  13  lon            15263 non-null  float64
#  14  budget         15263 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(7)
# memory usage: 1.9+ MB

# %%
df_2017.head()
# Out:
#        order_number order_date   customer_name    channel product_name  \
# 46363  SO - 0002544 2017-01-01       NCS Group  Wholesale   Product 30
# 46364  SO - 0006431 2017-01-01      Epic Group  Wholesale   Product 13
# 46365  SO - 0007491 2017-01-01       State Ltd  Wholesale   Product 15
# 46366  SO - 0008741 2017-01-01  Fivebridge Ltd  Wholesale    Product 8
# 46367  SO - 0009295 2017-01-01     Tagfeed Ltd  Wholesale    Product 2
#
#        quantity  unit_price  revenue      cost state  state_name  us_region  \
# 46363         6      1239.5   7437.0  1028.785    NJ  New Jersey  Northeast
# 46364         5      1829.1   9145.5  1207.206    CO    Colorado       West
# 46365         9      2412.0  21708.0  1664.280    CA  California       West
# 46366         8       904.5   7236.0   750.735    IA        Iowa    Midwest
# 46367        12      1112.2  13346.4   811.906    FL     Florida      South
#
#             lat        lon       budget
# 46363  40.77955  -74.02375  1011609.684
# ...

# %%
df_2017.isnull().sum()
# Out:
# order_number     0
# order_date       0
# customer_name    0
# channel          0
# product_name     0
# quantity         0
# unit_price       0
# revenue          0
# cost             0
# state            0
# state_name       0
# us_region        0
# lat              0
# lon              0
# budget           0
# dtype: int64

# %% [markdown]
# ## Feature Engineering

# %%
df.head()
# Out:
#    order_number order_date     customer_name      channel product_name  \
# 0   SO - 000225 2014-01-01     Rhynoodle Ltd    Wholesale   Product 27
# 1  SO - 0003378 2014-01-01    Thoughtmix Ltd  Distributor   Product 20
# 2  SO - 0005126 2014-01-01   Amerisourc Corp    Wholesale   Product 26
# 3  SO - 0005614 2014-01-01  Colgate-Pa Group       Export    Product 7
# 4  SO - 0005781 2014-01-01     Deseret Group    Wholesale    Product 8
#
#    quantity  unit_price  revenue      cost state   state_name  us_region  \
# 0         6      2499.1  14994.6  1824.343    GA      Georgia      South
# 1        11      2351.7  25868.7  1269.918    IN      Indiana    Midwest
# 2         6       978.2   5869.2   684.740    CA   California       West
# 3         7      2338.3  16368.1  1028.852    IN      Indiana    Midwest
# 4         8      2291.4  18331.2  1260.270    CT  Connecticut  Northeast
#
#         lat        lon  budget
# 0  32.08354  -81.09983     NaN
# 1  39.61366  -86.10665     NaN
# ...

# %%
# 1. Calculate total cost for each line item
df['total_cost'] = df['quantity'] * df['cost']

# %%
# 2. Calculate profit as revenue minus total_cost
df['profit'] = df['revenue'] - df['total_cost']

# %%
# 3. Calculate profit margin as a percentage
df['profit_margin_pct'] = (df['profit'] / df['revenue']) * 100

# %%
# 4. Extract full month name from order_date for labeling (e.g., 'January', 'February')
df['order_month_name'] = df['order_date'].dt.month_name()

# %%
# 5. Extract month number from order_date for correct sorting (1–12)
df['order_month_num'] = df['order_date'].dt.month

# %%
# Display the updated DataFrame
df
# Out:
#        order_number order_date     customer_name      channel product_name  \
# 0       SO - 000225 2014-01-01     Rhynoodle Ltd    Wholesale   Product 27
# 1      SO - 0003378 2014-01-01    Thoughtmix Ltd  Distributor   Product 20
# 2      SO - 0005126 2014-01-01   Amerisourc Corp    Wholesale   Product 26
# 3      SO - 0005614 2014-01-01  Colgate-Pa Group       Export    Product 7
# 4      SO - 0005781 2014-01-01     Deseret Group    Wholesale    Product 8
# ...             ...        ...               ...          ...          ...
# 64099  SO - 0007573 2018-02-28   Dazzlesphe Corp    Wholesale   Product 26
# 64100  SO - 0007706 2018-02-28        Yombu Corp       Export   Product 21
# 64101  SO - 0007718 2018-02-28        Bath Group  Distributor   Product 13
# 64102  SO - 0008084 2018-02-28     Linklinks Ltd  Distributor   Product 20
# 64103  SO - 0008654 2018-02-28       SAFEWAY Ltd  Distributor   Product 15
#
# ...
